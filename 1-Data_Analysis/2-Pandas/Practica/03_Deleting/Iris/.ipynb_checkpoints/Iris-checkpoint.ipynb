# %% [markdown]
# # 03 - Deleting & handling missing values - Iris

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data).

# %%
iris = pd.read_csv("iris.data")

# %% [markdown]
# ### Step 3. Assign it to a variable called iris

# %%
iris.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %% [markdown]
# ### Step 4. Call the columns for the dataset as follows:
# 1. sepal_length (in cm)
# 2. sepal_width (in cm)
# 3. petal_length (in cm)
# 4. petal_width (in cm)
# 5. class

# %%
iris.rename(columns = {"5.1":"sepal_length (in cm)", "3.5":"sepal_width (in cm)", "1.4" :"petal_length (in cm)", "0.2":"petal_width (in cm)", "Iris-setosa":"class" }, inplace = True)

# %%
iris
# Out:
#      sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 0                     4.9                  3.0                   1.4
# 1                     4.7                  3.2                   1.3
# 2                     4.6                  3.1                   1.5
# 3                     5.0                  3.6                   1.4
# 4                     5.4                  3.9                   1.7
# ..                    ...                  ...                   ...
# 144                   6.7                  3.0                   5.2
# 145                   6.3                  2.5                   5.0
# 146                   6.5                  3.0                   5.2
# 147                   6.2                  3.4                   5.4
# 148                   5.9                  3.0                   5.1
#
#      petal_width (in cm)           class
# 0                    0.2     Iris-setosa
# 1                    0.2     Iris-setosa
# 2                    0.2     Iris-setosa
# 3                    0.2     Iris-setosa
# 4                    0.4     Iris-setosa
# ..                   ...             ...
# 144                  2.3  Iris-virginica
# 145                  1.9  Iris-virginica
# 146                  2.0  Iris-virginica
# 147                  2.3  Iris-virginica
# 148                  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %% [markdown]
# ### Step 5.  Is there any missing value in the dataframe?

# %%
iris.isnull().sum()
# Out:
# sepal_length (in cm)    0
# sepal_width (in cm)     0
# petal_length (in cm)    0
# petal_width (in cm)     0
# class                   0
# dtype: int64

# %% [markdown]
# ### Step 6.  Lets set the values of the rows 10 to 29 of the column 'petal_length' to NaN

# %%
iris.iloc[10:30,:]["petal_length (in cm)"] = pd.np.nan
# Out:
# <ipython-input-7-2091cdee3a82>:1: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   iris.iloc[10:30,:]["petal_length (in cm)"] = pd.np.nan
# <ipython-input-7-2091cdee3a82>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iris.iloc[10:30,:]["petal_length (in cm)"] = pd.np.nan

# %%
iris.iloc[10:30,:]["petal_length (in cm)"]
# Out:
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# 20   NaN
# 21   NaN
# 22   NaN
# 23   NaN
# 24   NaN
# 25   NaN
# 26   NaN
# 27   NaN
# 28   NaN
# 29   NaN
# Name: petal_length (in cm), dtype: float64

# %%
iris.isnull().sum()
# Out:
# sepal_length (in cm)     0
# sepal_width (in cm)      0
# petal_length (in cm)    20
# petal_width (in cm)      0
# class                    0
# dtype: int64

# %% [markdown]
# ### Step 7. Good, now lets substitute the NaN values to 1.0

# %%
iris.fillna(1.0)
# Out:
#      sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 0                     4.9                  3.0                   1.4
# 1                     4.7                  3.2                   1.3
# 2                     4.6                  3.1                   1.5
# 3                     5.0                  3.6                   1.4
# 4                     5.4                  3.9                   1.7
# ..                    ...                  ...                   ...
# 144                   6.7                  3.0                   5.2
# 145                   6.3                  2.5                   5.0
# 146                   6.5                  3.0                   5.2
# 147                   6.2                  3.4                   5.4
# 148                   5.9                  3.0                   5.1
#
#      petal_width (in cm)           class
# 0                    0.2     Iris-setosa
# 1                    0.2     Iris-setosa
# 2                    0.2     Iris-setosa
# 3                    0.2     Iris-setosa
# 4                    0.4     Iris-setosa
# ..                   ...             ...
# 144                  2.3  Iris-virginica
# 145                  1.9  Iris-virginica
# 146                  2.0  Iris-virginica
# 147                  2.3  Iris-virginica
# 148                  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %% [markdown]
# ### Step 8. Now let's delete the column class

# %%
iris.drop("class", axis =1)
# Out:
#      sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 0                     4.9                  3.0                   1.4
# 1                     4.7                  3.2                   1.3
# 2                     4.6                  3.1                   1.5
# 3                     5.0                  3.6                   1.4
# 4                     5.4                  3.9                   1.7
# ..                    ...                  ...                   ...
# 144                   6.7                  3.0                   5.2
# 145                   6.3                  2.5                   5.0
# 146                   6.5                  3.0                   5.2
# 147                   6.2                  3.4                   5.4
# 148                   5.9                  3.0                   5.1
#
#      petal_width (in cm)
# 0                    0.2
# 1                    0.2
# 2                    0.2
# 3                    0.2
# 4                    0.4
# ..                   ...
# 144                  2.3
# 145                  1.9
# 146                  2.0
# 147                  2.3
# 148                  1.8
#
# [149 rows x 4 columns]

# %% [markdown]
# ### Step 9.  Set the first 3 rows as NaN

# %%
iris[0:3]= None
iris
# Out:
#      sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 0                     NaN                  NaN                   NaN
# 1                     NaN                  NaN                   NaN
# 2                     NaN                  NaN                   NaN
# 3                     5.0                  3.6                   1.4
# 4                     5.4                  3.9                   1.7
# ..                    ...                  ...                   ...
# 144                   6.7                  3.0                   5.2
# 145                   6.3                  2.5                   5.0
# 146                   6.5                  3.0                   5.2
# 147                   6.2                  3.4                   5.4
# 148                   5.9                  3.0                   5.1
#
#      petal_width (in cm)           class
# 0                    NaN            None
# 1                    NaN            None
# 2                    NaN            None
# 3                    0.2     Iris-setosa
# 4                    0.4     Iris-setosa
# ..                   ...             ...
# 144                  2.3  Iris-virginica
# 145                  1.9  Iris-virginica
# 146                  2.0  Iris-virginica
# 147                  2.3  Iris-virginica
# 148                  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %% [markdown]
# ### Step 10.  Delete the rows that have NaN

# %%
iris.dropna(axis=0)
# Out:
#      sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 3                     5.0                  3.6                   1.4
# 4                     5.4                  3.9                   1.7
# 5                     4.6                  3.4                   1.4
# 6                     5.0                  3.4                   1.5
# 7                     4.4                  2.9                   1.4
# ..                    ...                  ...                   ...
# 144                   6.7                  3.0                   5.2
# 145                   6.3                  2.5                   5.0
# 146                   6.5                  3.0                   5.2
# 147                   6.2                  3.4                   5.4
# 148                   5.9                  3.0                   5.1
#
#      petal_width (in cm)           class
# 3                    0.2     Iris-setosa
# 4                    0.4     Iris-setosa
# 5                    0.3     Iris-setosa
# 6                    0.2     Iris-setosa
# 7                    0.2     Iris-setosa
# ..                   ...             ...
# 144                  2.3  Iris-virginica
# 145                  1.9  Iris-virginica
# 146                  2.0  Iris-virginica
# 147                  2.3  Iris-virginica
# 148                  1.8  Iris-virginica
#
# [126 rows x 5 columns]

# %% [markdown]
# ### Step 11. Reset the index so it begins with 0 again

# %%
iris.reset_index()
# Out:
#      index  sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 0        0                   NaN                  NaN                   NaN
# 1        1                   NaN                  NaN                   NaN
# 2        2                   NaN                  NaN                   NaN
# 3        3                   5.0                  3.6                   1.4
# 4        4                   5.4                  3.9                   1.7
# ..     ...                   ...                  ...                   ...
# 144    144                   6.7                  3.0                   5.2
# 145    145                   6.3                  2.5                   5.0
# 146    146                   6.5                  3.0                   5.2
# 147    147                   6.2                  3.4                   5.4
# 148    148                   5.9                  3.0                   5.1
#
#      petal_width (in cm)           class
# 0                    NaN            None
# 1                    NaN            None
# 2                    NaN            None
# 3                    0.2     Iris-setosa
# 4                    0.4     Iris-setosa
# ..                   ...             ...
# 144                  2.3  Iris-virginica
# 145                  1.9  Iris-virginica
# 146                  2.0  Iris-virginica
# 147                  2.3  Iris-virginica
# 148                  1.8  Iris-virginica
#
# [149 rows x 6 columns]
