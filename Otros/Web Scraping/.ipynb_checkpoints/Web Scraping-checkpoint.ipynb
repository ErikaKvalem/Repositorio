# %% [markdown]
# # Extracción de datos web

# %% [markdown]
# ## Índice
# 1. [Navegador web en Python (socket)](#socket)
# 2. [Recepción de páginas web con urllib](#urllib)
# 3. [Parsing de HTML mediante BeatifulSoup](#bea)
# 4. [Ejemplos de web scraping](#ejemplos)
# 5. [Web scraping con selenium](#sele)

# %% [markdown]
# <a id="socket"></a>
# ## Navegador web en Python (socket)

# %% [markdown]
# Vamos a crear nuestro primer navegador web utilizando el protocolo HTTP, realizando una conexión a un servidor web siguiendo las reglas de este protocolo para solicitar un documento y mostrar lo que el servidor nos devuelve. El documento al que accederemos se encuentra en la página web https://www.w3.org/TR/PNG/iso_8859-1.txt

# %%
import socket

mysock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
mysock.connect(('www.w3.org', 80))
cmd = 'GET https://www.w3.org/TR/PNG/iso_8859-1.txt HTTP/1.0\r\n\r\n'.encode()
mysock.send(cmd)

while True:
    data = mysock.recv(512)
    if len(data) < 1:
        break
    print(data.decode(),end='')

mysock.close()
# Out:
# HTTP/1.1 200 OK
# date: Tue, 23 Mar 2021 17:39:34 GMT
# last-modified: Fri, 07 Nov 2003 05:51:11 GMT
# etag: "17e9-3cb82080711c0;50c0b26855880"
# accept-ranges: bytes
# content-length: 6121
# cache-control: max-age=31536000
# expires: Wed, 23 Mar 2022 17:39:34 GMT
# vary: Accept-Encoding,upgrade-insecure-requests
# access-control-allow-origin: *
# keep-alive: timeout=5, max=2000
# content-type: text/plain
# x-backend: www-mirrors
# connection: close
#
# The following are the graphical (non-control) characters defined by
# ISO 8859-1 (1987).  Descriptions in words aren't all that helpful,
# but they're the best we can do in text.  A graphics file illustrating
# the character set should be available from the same archive as this
# file.
#
# Hex Description                 Hex Description
#
# 20  SPACE
# 21  EXCLAMATION MARK            A1  INVERTED EXCLAMATION MARK
# 22  QUOTATION MARK              A2  CENT SIGN
# 23  NUMBER SIGN                 A3  POUND SIGN
# 24  DOLLAR SIGN                 A4  CURRENCY SIGN
# 25  PERCENT SIGN                A5  YEN SIGN
# 26  AMPERSAND                   A6  BROKEN BAR
# 27  APOSTROPHE                  A7  SECTION SIGN
# 28  LEFT PARENTHESIS            A8  DIAERESIS
# 29  RIGHT PARENTHESIS           A9  COPYRIGHT SIGN
# 2A  ASTERISK                    AA  FEMININE ORDINAL INDICATOR
# 2B  PLUS SIGN                   AB  LEFT-POINTING DOUBLE ANGLE QUOTATION MARK
# 2C  COMMA                       AC  NOT SIGN
# 2D  HYPHEN-MINUS                AD  SOFT HYPHEN
# 2E  FULL STOP                   AE  REGISTERED SIGN
# 2F  SOLIDUS                     AF  OVERLINE
# 30  DIGIT ZERO                  B0  DEGREE SIGN
# 31  DIGIT ONE                   B1  PLUS-MINUS SIGN
# 32  DIGIT TWO                   B2  SUPERSCRIPT TWO
# 33  DIGIT THREE                 B3  SUPERSCRIPT THREE
# 34  DIGIT FOUR                  B4  ACUTE ACCENT
# 35  DIGIT FIVE                  B5  MICRO SIGN
# 36  DIGIT SIX                   B6  PILCROW SIGN
# 37  DIGIT SEVEN                 B7  MIDDLE DOT
# 38  DIGIT EIGHT                 B8  CEDILLA
# 39  DIGIT NINE                  B9  SUPERSCRIPT ONE
# 3A  COLON                       BA  MASCULINE ORDINAL INDICATOR
# 3B  SEMICOLON                   BB  RIGHT-POINTING DOUBLE ANGLE QUOTATION MARK
# 3C  LESS-THAN SIGN              BC  VULGAR FRACTION ONE QUARTER
# 3D  EQUALS SIGN                 BD  VULGAR FRACTION ONE HALF
# 3E  GREATER-THAN SIGN           BE  VULGAR FRACTION THREE QUARTERS
# 3F  QUESTION MARK               BF  INVERTED QUESTION MARK
# 40  COMMERCIAL AT               C0  CAPITAL LETTER A WITH GRAVE
# 41  CAPITAL LETTER A            C1  CAPITAL LETTER A WITH ACUTE
# 42  CAPITAL LETTER B            C2  CAPITAL LETTER A WITH CIRCUMFLEX
# 43  CAPITAL LETTER C            C3  CAPITAL LETTER A WITH TILDE
# 44  CAPITAL LETTER D            C4  CAPITAL LETTER A WITH DIAERESIS
# 45  CAPITAL LETTER E            C5  CAPITAL LETTER A WITH RING ABOVE
# 46  CAPITAL LETTER F            C6  CAPITAL LETTER AE
# 47  CAPITAL LETTER G            C7  CAPITAL LETTER C WITH CEDILLA
# 48  CAPITAL LETTER H            C8  CAPITAL LETTER E WITH GRAVE
# 49  CAPITAL LETTER I            C9  CAPITAL LETTER E WITH ACUTE
# 4A  CAPITAL LETTER J            CA  CAPITAL LETTER E WITH CIRCUMFLEX
# 4B  CAPITAL LETTER K            CB  CAPITAL LETTER E WITH DIAERESIS
# 4C  CAPITAL LETTER L            CC  CAPITAL LETTER I WITH GRAVE
# 4D  CAPITAL LETTER M            CD  CAPITAL LETTER I WITH ACUTE
# 4E  CAPITAL LETTER N            CE  CAPITAL LETTER I WITH CIRCUMFLEX
# 4F  CAPITAL LETTER O            CF  CAPITAL LETTER I WITH DIAERESIS
# 50  CAPITAL LETTER P            D0  CAPITAL LETTER ETH (Icelandic)
# 51  CAPITAL LETTER Q            D1  CAPITAL LETTER N WITH TILDE
# 52  CAPITAL LETTER R            D2  CAPITAL LETTER O WITH GRAVE
# 53  CAPITAL LETTER S            D3  CAPITAL LETTER O WITH ACUTE
# 54  CAPITAL LETTER T            D4  CAPITAL LETTER O WITH CIRCUMFLEX
# 55  CAPITAL LETTER U            D5  CAPITAL LETTER O WITH TILDE
# 56  CAPITAL LETTER V            D6  CAPITAL LETTER O WITH DIAERESIS
# 57  CAPITAL LETTER W            D7  MULTIPLICATION SIGN
# 58  CAPITAL LETTER X            D8  CAPITAL LETTER O WITH STROKE
# 59  CAPITAL LETTER Y            D9  CAPITAL LETTER U WITH GRAVE
# 5A  CAPITAL LETTER Z            DA  CAPITAL LETTER U WITH ACUTE
# 5B  LEFT SQUARE BRACKET         DB  CAPITAL LETTER U WITH CIRCUMFLEX
# 5C  REVERSE SOLIDUS             DC  CAPITAL LETTER U WITH DIAERESIS
# 5D  RIGHT SQUARE BRACKET        DD  CAPITAL LETTER Y WITH ACUTE
# 5E  CIRCUMFLEX ACCENT           DE  CAPITAL LETTER THORN (Icelandic)
# 5F  LOW LINE                    DF  SMALL LETTER SHARP S (German)
# 60  GRAVE ACCENT                E0  SMALL LETTER A WITH GRAVE
# 61  SMALL LETTER A              E1  SMALL LETTER A WITH ACUTE
# 62  SMALL LETTER B              E2  SMALL LETTER A WITH CIRCUMFLEX
# 63  SMALL LETTER C              E3  SMALL LETTER A WITH TILDE
# 64  SMALL LETTER D              E4  SMALL LETTER A WITH DIAERESIS
# 65  SMALL LETTER E              E5  SMALL LETTER A WITH RING ABOVE
# 66  SMALL LETTER F              E6  SMALL LETTER AE
# 67  SMALL LETTER G              E7  SMALL LETTER C WITH CEDILLA
# 68  SMALL LETTER H              E8  SMALL LETTER E WITH GRAVE
# 69  SMALL LETTER I              E9  SMALL LETTER E WITH ACUTE
# 6A  SMALL LETTER J              EA  SMALL LETTER E WITH CIRCUMFLEX
# 6B  SMALL LETTER K              EB  SMALL LETTER E WITH DIAERESIS
# 6C  SMALL LETTER L              EC  SMALL LETTER I WITH GRAVE
# 6D  SMALL LETTER M              ED  SMALL LETTER I WITH ACUTE
# 6E  SMALL LETTER N              EE  SMALL LETTER I WITH CIRCUMFLEX
# 6F  SMALL LETTER O              EF  SMALL LETTER I WITH DIAERESIS
# 70  SMALL LETTER P              F0  SMALL LETTER ETH (Icelandic)
# 71  SMALL LETTER Q              F1  SMALL LETTER N WITH TILDE
# 72  SMALL LETTER R              F2  SMALL LETTER O WITH GRAVE
# 73  SMALL LETTER S              F3  SMALL LETTER O WITH ACUTE
# 74  SMALL LETTER T              F4  SMALL LETTER O WITH CIRCUMFLEX
# 75  SMALL LETTER U              F5  SMALL LETTER O WITH TILDE
# 76  SMALL LETTER V              F6  SMALL LETTER O WITH DIAERESIS
# 77  SMALL LETTER W              F7  DIVISION SIGN
# 78  SMALL LETTER X              F8  SMALL LETTER O WITH STROKE
# 79  SMALL LETTER Y              F9  SMALL LETTER U WITH GRAVE
# 7A  SMALL LETTER Z              FA  SMALL LETTER U WITH ACUTE
# 7B  LEFT CURLY BRACKET          FB  SMALL LETTER U WITH CIRCUMFLEX
# 7C  VERTICAL LINE               FC  SMALL LETTER U WITH DIAERESIS
# 7D  RIGHT CURLY BRACKET         FD  SMALL LETTER Y WITH ACUTE
# 7E  TILDE                       FE  SMALL LETTER THORN (Icelandic)
#                                 FF  SMALL LETTER Y WITH DIAERESIS

# %% [markdown]
# Primero, el programa realiza una conexión al puerto 80 del servidor www.w3.org. Como nuestro programa está asumiendo el rol de "navegador web", el protocolo HTTP nos dice que tenemos que enviar el comando GET seguido por una línea en blanco. `\r\n` significa un final de línea, y `\r\n\r\n` es el equivalente a la línea en blanco.

# %% [markdown]
# <a id="urllib"></a>
# ## Recepción de páginas web con urllib

# %%
import urllib.request
f = urllib.request.urlopen("https://www.w3.org/TR/PNG/iso_8859-1.txt")
print(f.read().decode())
# Out:
# The following are the graphical (non-control) characters defined by
# ISO 8859-1 (1987).  Descriptions in words aren't all that helpful,
# but they're the best we can do in text.  A graphics file illustrating
# the character set should be available from the same archive as this
# file.
#
# Hex Description                 Hex Description
#
# 20  SPACE
# 21  EXCLAMATION MARK            A1  INVERTED EXCLAMATION MARK
# 22  QUOTATION MARK              A2  CENT SIGN
# 23  NUMBER SIGN                 A3  POUND SIGN
# 24  DOLLAR SIGN                 A4  CURRENCY SIGN
# 25  PERCENT SIGN                A5  YEN SIGN
# 26  AMPERSAND                   A6  BROKEN BAR
# 27  APOSTROPHE                  A7  SECTION SIGN
# 28  LEFT PARENTHESIS            A8  DIAERESIS
# 29  RIGHT PARENTHESIS           A9  COPYRIGHT SIGN
# 2A  ASTERISK                    AA  FEMININE ORDINAL INDICATOR
# 2B  PLUS SIGN                   AB  LEFT-POINTING DOUBLE ANGLE QUOTATION MARK
# 2C  COMMA                       AC  NOT SIGN
# 2D  HYPHEN-MINUS                AD  SOFT HYPHEN
# 2E  FULL STOP                   AE  REGISTERED SIGN
# 2F  SOLIDUS                     AF  OVERLINE
# 30  DIGIT ZERO                  B0  DEGREE SIGN
# 31  DIGIT ONE                   B1  PLUS-MINUS SIGN
# 32  DIGIT TWO                   B2  SUPERSCRIPT TWO
# 33  DIGIT THREE                 B3  SUPERSCRIPT THREE
# 34  DIGIT FOUR                  B4  ACUTE ACCENT
# 35  DIGIT FIVE                  B5  MICRO SIGN
# 36  DIGIT SIX                   B6  PILCROW SIGN
# 37  DIGIT SEVEN                 B7  MIDDLE DOT
# 38  DIGIT EIGHT                 B8  CEDILLA
# 39  DIGIT NINE                  B9  SUPERSCRIPT ONE
# 3A  COLON                       BA  MASCULINE ORDINAL INDICATOR
# 3B  SEMICOLON                   BB  RIGHT-POINTING DOUBLE ANGLE QUOTATION MARK
# 3C  LESS-THAN SIGN              BC  VULGAR FRACTION ONE QUARTER
# 3D  EQUALS SIGN                 BD  VULGAR FRACTION ONE HALF
# 3E  GREATER-THAN SIGN           BE  VULGAR FRACTION THREE QUARTERS
# 3F  QUESTION MARK               BF  INVERTED QUESTION MARK
# 40  COMMERCIAL AT               C0  CAPITAL LETTER A WITH GRAVE
# 41  CAPITAL LETTER A            C1  CAPITAL LETTER A WITH ACUTE
# 42  CAPITAL LETTER B            C2  CAPITAL LETTER A WITH CIRCUMFLEX
# 43  CAPITAL LETTER C            C3  CAPITAL LETTER A WITH TILDE
# 44  CAPITAL LETTER D            C4  CAPITAL LETTER A WITH DIAERESIS
# 45  CAPITAL LETTER E            C5  CAPITAL LETTER A WITH RING ABOVE
# 46  CAPITAL LETTER F            C6  CAPITAL LETTER AE
# 47  CAPITAL LETTER G            C7  CAPITAL LETTER C WITH CEDILLA
# 48  CAPITAL LETTER H            C8  CAPITAL LETTER E WITH GRAVE
# 49  CAPITAL LETTER I            C9  CAPITAL LETTER E WITH ACUTE
# 4A  CAPITAL LETTER J            CA  CAPITAL LETTER E WITH CIRCUMFLEX
# 4B  CAPITAL LETTER K            CB  CAPITAL LETTER E WITH DIAERESIS
# 4C  CAPITAL LETTER L            CC  CAPITAL LETTER I WITH GRAVE
# 4D  CAPITAL LETTER M            CD  CAPITAL LETTER I WITH ACUTE
# 4E  CAPITAL LETTER N            CE  CAPITAL LETTER I WITH CIRCUMFLEX
# 4F  CAPITAL LETTER O            CF  CAPITAL LETTER I WITH DIAERESIS
# 50  CAPITAL LETTER P            D0  CAPITAL LETTER ETH (Icelandic)
# 51  CAPITAL LETTER Q            D1  CAPITAL LETTER N WITH TILDE
# 52  CAPITAL LETTER R            D2  CAPITAL LETTER O WITH GRAVE
# 53  CAPITAL LETTER S            D3  CAPITAL LETTER O WITH ACUTE
# 54  CAPITAL LETTER T            D4  CAPITAL LETTER O WITH CIRCUMFLEX
# 55  CAPITAL LETTER U            D5  CAPITAL LETTER O WITH TILDE
# 56  CAPITAL LETTER V            D6  CAPITAL LETTER O WITH DIAERESIS
# 57  CAPITAL LETTER W            D7  MULTIPLICATION SIGN
# 58  CAPITAL LETTER X            D8  CAPITAL LETTER O WITH STROKE
# 59  CAPITAL LETTER Y            D9  CAPITAL LETTER U WITH GRAVE
# 5A  CAPITAL LETTER Z            DA  CAPITAL LETTER U WITH ACUTE
# 5B  LEFT SQUARE BRACKET         DB  CAPITAL LETTER U WITH CIRCUMFLEX
# 5C  REVERSE SOLIDUS             DC  CAPITAL LETTER U WITH DIAERESIS
# 5D  RIGHT SQUARE BRACKET        DD  CAPITAL LETTER Y WITH ACUTE
# 5E  CIRCUMFLEX ACCENT           DE  CAPITAL LETTER THORN (Icelandic)
# 5F  LOW LINE                    DF  SMALL LETTER SHARP S (German)
# 60  GRAVE ACCENT                E0  SMALL LETTER A WITH GRAVE
# 61  SMALL LETTER A              E1  SMALL LETTER A WITH ACUTE
# 62  SMALL LETTER B              E2  SMALL LETTER A WITH CIRCUMFLEX
# 63  SMALL LETTER C              E3  SMALL LETTER A WITH TILDE
# 64  SMALL LETTER D              E4  SMALL LETTER A WITH DIAERESIS
# 65  SMALL LETTER E              E5  SMALL LETTER A WITH RING ABOVE
# 66  SMALL LETTER F              E6  SMALL LETTER AE
# 67  SMALL LETTER G              E7  SMALL LETTER C WITH CEDILLA
# 68  SMALL LETTER H              E8  SMALL LETTER E WITH GRAVE
# 69  SMALL LETTER I              E9  SMALL LETTER E WITH ACUTE
# 6A  SMALL LETTER J              EA  SMALL LETTER E WITH CIRCUMFLEX
# 6B  SMALL LETTER K              EB  SMALL LETTER E WITH DIAERESIS
# 6C  SMALL LETTER L              EC  SMALL LETTER I WITH GRAVE
# 6D  SMALL LETTER M              ED  SMALL LETTER I WITH ACUTE
# 6E  SMALL LETTER N              EE  SMALL LETTER I WITH CIRCUMFLEX
# 6F  SMALL LETTER O              EF  SMALL LETTER I WITH DIAERESIS
# 70  SMALL LETTER P              F0  SMALL LETTER ETH (Icelandic)
# 71  SMALL LETTER Q              F1  SMALL LETTER N WITH TILDE
# 72  SMALL LETTER R              F2  SMALL LETTER O WITH GRAVE
# 73  SMALL LETTER S              F3  SMALL LETTER O WITH ACUTE
# 74  SMALL LETTER T              F4  SMALL LETTER O WITH CIRCUMFLEX
# 75  SMALL LETTER U              F5  SMALL LETTER O WITH TILDE
# 76  SMALL LETTER V              F6  SMALL LETTER O WITH DIAERESIS
# 77  SMALL LETTER W              F7  DIVISION SIGN
# 78  SMALL LETTER X              F8  SMALL LETTER O WITH STROKE
# 79  SMALL LETTER Y              F9  SMALL LETTER U WITH GRAVE
# 7A  SMALL LETTER Z              FA  SMALL LETTER U WITH ACUTE
# 7B  LEFT CURLY BRACKET          FB  SMALL LETTER U WITH CIRCUMFLEX
# 7C  VERTICAL LINE               FC  SMALL LETTER U WITH DIAERESIS
# 7D  RIGHT CURLY BRACKET         FD  SMALL LETTER Y WITH ACUTE
# 7E  TILDE                       FE  SMALL LETTER THORN (Icelandic)
#                                 FF  SMALL LETTER Y WITH DIAERESIS

# %% [markdown]
# Cuando el programa se ejecuta, en su salida sólo vemos el contenido del fichero. Las cabeceras siguen enviándose, pero el código de `urllib` se queda con ella y sólo nos devuelve los datos. Una vez abierta la página web, se puede leer como si fuese un archivo local.
# ¿Qué ocurre si cambiamos el txt por otra página web?

# %% [markdown]
# <a id="bea"></a>
# ## Parsing de HTML mediante BeatifulSoup

# %% [markdown]
# BeautifulSoup es una librería de Python que permite analizar documentos HTML y extraer datos de ellos, compensando imperfecciones que puedan existir. Para instalar esta librería escribimos en anaconda Prompt:
# `conda install -c anaconda beautifulsoup4`

# %% [markdown]
# Esta librería permite, por ejemplo, extraer los atributos href de las etiquetas de anclaje (a)
# <img src='http://www.cellbiol.com/bioinformatics_web_development/wp-content/uploads/2017/01/attributes_and_values_in_the_a_tag.png'>
# En el siguiente ejemplo, vamos a parsear una entrada HTML y extraer los links utilizando la librería BeautifulSoup.
# Utilizaremos urllib para leer la página y después BeautifulSoup para extraer los atributos href de las etiquetas de tipo ancla (a)

# %%
import urllib.request
from bs4 import BeautifulSoup

# %%
url = input("Introduce URL: ")
html = urllib.request.urlopen(url)
soup = BeautifulSoup(html)
tags = soup("a")
# Out:
# Introduce URL: https://elpais.com/

# %%
for tag in tags:
    print(tag.get("href"))
# Out:
# https://elpais.com/
# https://www.mozilla.org/es-ES/firefox/new/
# https://www.microsoft.com/es-es/edge
# https://www.google.com/intl/es_es/chrome/
# https://support.apple.com/downloads/safari
# https://elpais.com/s/setEspana.html
# https://elpais.com/s/setAmerica.html
# https://elpais.com/s/setMexico.html
# https://elpais.com/s/setBrasil.html
# https://elpais.com/s/setCat.html
# https://elpais.com/s/setEnglish.html
# https://suscripciones.elpais.com/?prm=suscrip_cabecera_ep.com&prod=SUSDIG&o=boton_cab&backURL=NaN#/campaign
# https://elpais.com/subscriptions/#/sign-in?prod=REG&o=CABEP&backURL=https%3A%2F%2Felpais.com%2Fhomepage
# https://elpais.com/landing_oferta/#/campaignprod=SUSDIG&o=login_ep&backURL=NaN#/campaign
# https://elpais.com/subscriptions/#/profile
# https://elpais.com/subscriptions/#/manage
# https://plus.elpais.com/perfil/newsletters/
# https://elpais.com/suscripciones/elpaismas.html
# http://as.com/?por=mosaico
# https://as.com/futbol/2021/03/22/internacional/1616426470_560026.html
# https://as.com/meristation/noticias/?por=mosaico
# https://as.com/meristation/2021/03/23/noticias/1616481648_451571.html
# http://suscripciones.elpais.com/?prm=epm_faldonsuscribete_300614
# //redirector.kioskoymas.com/portada/elpais/2317
# //elpais.com/hemeroteca/elpais/portadas/2021/
# //redirector.kioskoymas.com/portada/elpais/2289
# //elpais.com/hemeroteca/el-pais-semanal/portadas/2021/
# //redirector.kioskoymas.com/portada/elpais/2317/
# //elviajero.elpais.com/hemeroteca/elviajero/portadas/2021/
# //redirector.kioskoymas.com/portada/elpais/2317/
# //elpais.com/hemeroteca/babelia/portadas/2021/
# //redirector.kioskoymas.com/portada/elpais/2330
# //redirector.kioskoymas.com/portada/elpais/3725
# http://suscripciones.elpais.com/?id_externo_promo=suscrip-pie-home
# http://suscripciones.elpais.com/?id_externo_promo=suscrip-pie-home
# http://suscripciones.elpais.com/?id_externo_promo=suscrip-pie-home
# https://elpais.com/tematicos/2021/03/16/elpaismas/1615889833_157488.html
# https://elpais.com/tematicos/2020/02/03/elpaismas/1580727455_194715.html
# https://suscripciones.elpais.com/?prm=epm_faldonsuscr%C3%ADbete_300614
# https://plus.elpais.com/newsletters/?prm=pie_newsletters_ep
# http://www.kioskoymas.com/publicacion/elpais
# //elpais.com/corporativos/
# //elpais.com/estaticos/contacte/
# //www.prisanewsservices.com/
# //elpais.com/estaticos/aviso-legal/
# https://elpais.com/politica-de-cookies/
# #
# https://elpais.com/estaticos/politica-privacidad/
# //elpais.com/estaticos/mapa-web/
# //elpais.com/landing_oferta/
# https://elpais.com/suscripciones/empresas/
# //servicios.elpais.com/rss/
# //elpais.com/tag/listado/
# https://elpais.com/actualidad/

# %% [markdown]
# Podemos extraer más campos de las etiquetas

# %%
for tag in tags:
    print("URL: ", tag.get("href"))
    print("Contenido: ", tag.contents)
    print("Atributos:", tag.attrs)
    print("\n")
# Out:
# URL:  https://elpais.com/
# Contenido:  ['El País']
# Atributos: {'href': 'https://elpais.com/'}
#
#
# URL:  https://www.mozilla.org/es-ES/firefox/new/
# Contenido:  ['Mozilla Firefox']
# Atributos: {'href': 'https://www.mozilla.org/es-ES/firefox/new/'}
#
#
# URL:  https://www.microsoft.com/es-es/edge
# Contenido:  ['Microsoft Edge']
# Atributos: {'href': 'https://www.microsoft.com/es-es/edge'}
#
#
# URL:  https://www.google.com/intl/es_es/chrome/
# Contenido:  ['Google Chrome']
# Atributos: {'href': 'https://www.google.com/intl/es_es/chrome/'}
#
#
# URL:  https://support.apple.com/downloads/safari
# Contenido:  ['Safari']
# Atributos: {'href': 'https://support.apple.com/downloads/safari'}
#
#
# URL:  https://elpais.com/s/setEspana.html
# Contenido:  ['esp']
# Atributos: {'id': 'edition-link-el-pais', 'href': 'https://elpais.com/s/setEspana.html', 'class': ['current']}
#
#
# URL:  https://elpais.com/s/setAmerica.html
# Contenido:  ['ame']
# Atributos: {'id': 'edition-link-el-pais-america', 'href': 'https://elpais.com/s/setAmerica.html', 'class': []}
#
#
# URL:  https://elpais.com/s/setMexico.html
# Contenido:  ['mex']
# Atributos: {'id': 'edition-link-el-pais-mexico', 'href': 'https://elpais.com/s/setMexico.html', 'class': []}
#
#
# URL:  https://elpais.com/s/setBrasil.html
# Contenido:  ['bra']
# Atributos: {'id': 'edition-link-el-pais-brasil', 'href': 'https://elpais.com/s/setBrasil.html', 'class': []}
#
#
# URL:  https://elpais.com/s/setCat.html
# Contenido:  ['cat']
# Atributos: {'id': 'edition-link-el-pais-cataluna', 'href': 'https://elpais.com/s/setCat.html', 'class': []}
#
#
# URL:  https://elpais.com/s/setEnglish.html
# Contenido:  ['eng']
# Atributos: {'id': 'edition-link-el-pais-in-english', 'href': 'https://elpais.com/s/setEnglish.html', 'class': []}
#
#
# URL:  https://suscripciones.elpais.com/?prm=suscrip_cabecera_ep.com&prod=SUSDIG&o=boton_cab&backURL=NaN#/campaign
# Contenido:  ['suscríbete']
# Atributos: {'class': ['button', 'button_primary', '|', 'flex', 'subscribe', '|', 'relative', 'padding_left_sm', 'align_items_center', 'no_hover', 'logged_user_subscribeOutside', 'bold', 'whitespace_nowrap', 'align_items_center', 'border-box'], 'href': 'https://suscripciones.elpais.com/?prm=suscrip_cabecera_ep.com&prod=SUSDIG&o=boton_cab&backURL=NaN#/campaign', 'id': ''}
#
#
# URL:  https://elpais.com/subscriptions/#/sign-in?prod=REG&o=CABEP&backURL=https%3A%2F%2Felpais.com%2Fhomepage
# Contenido:  [<span class="user_initials | border_1 border_solid border_round flex justify_center align_items_center border-box"><svg class="icon_portal_login_subscriber | user_icon | relative color_gray_light" viewbox="0 0 26 23"><g fill="none" fill-rule="evenodd" stroke="none" stroke-width="1"><g fill="currentColor" transform="translate(-316.000000, -7.000000)"><g transform="translate(282.000000, 7.000000)"><g transform="translate(34.000000, 0.000000)"><path d="M-2.82440737e-13,13.1611427 C-2.82440737e-13,5.90393376 5.83164706,0 13,0 C20.1683529,0 26,5.90393376 26,13.1611427 C26,17.0718085 24.304902,20.58764 21.6212941,23 C21.4714118,22.895227 21.3205098,22.8012926 21.1660392,22.7228418 L16.8495294,20.5380921 C16.4620784,20.3419653 16.221451,19.9476472 16.221451,19.5094585 L16.221451,17.9832821 C16.3213725,17.8583803 16.426902,17.7169625 16.536,17.5616094 C17.0947451,16.7626506 17.5428627,15.8738864 17.8696471,14.91751 C18.5155686,14.6068039 18.9325882,13.9554563 18.9325882,13.2199807 L18.9325882,11.3903238 C18.9325882,10.942845 18.7704706,10.5087853 18.4803922,10.1676279 L18.4803922,7.75888069 C18.506902,7.4904966 18.6007059,5.97928775 17.5204314,4.732334 C16.5808627,3.6464107 15.0601176,3.09673945 13,3.09673945 C10.9398824,3.09673945 9.41913725,3.6464107 8.47956863,4.73181788 C7.39929412,5.97877163 7.49309804,7.49101272 7.51960784,7.75836456 L7.51960784,10.1671117 C7.23003922,10.5082692 7.06741176,10.9423288 7.06741176,11.3898077 L7.06741176,13.2194646 C7.06741176,13.7877163 7.3192549,14.3177748 7.75054902,14.6754482 C8.1634902,16.3131073 9.01333333,17.5528353 9.32737255,17.9729596 L9.32737255,19.4666203 C9.32737255,19.8877769 9.1005098,20.2748693 8.73498039,20.4771896 L4.70396078,22.7032291 C4.5754902,22.773938 4.44803922,22.8565177 4.32058824,22.9489038 C1.67011765,20.537576 -2.82440737e-13,17.0434217 -2.82440737e-13,13.1611427 Z"></path></g></g></g></g></svg></span>, <span class="user_login | hidden_mobile uppercase whitespace_nowrap">Iniciar sesión</span>]
# Atributos: {'href': 'https://elpais.com/subscriptions/#/sign-in?prod=REG&o=CABEP&backURL=https%3A%2F%2Felpais.com%2Fhomepage', 'class': ['user_profile', '|', 'bold', 'flex', 'height_full', 'width_full', 'z_index_50', 'align_items_center', 'border-box'], 'id': 'not_logged_user_'}
#
#
# URL:  https://elpais.com/landing_oferta/#/campaignprod=SUSDIG&o=login_ep&backURL=NaN#/campaign
# Contenido:  ['suscríbete por 1€']
# Atributos: {'href': 'https://elpais.com/landing_oferta/#/campaignprod=SUSDIG&o=login_ep&backURL=NaN#/campaign', 'class': ['button', 'button__offer', '|', 'flex_inline', 'margin_vertical', 'bold', 'color_white', 'uppercase', 'no_hover'], 'id': 'logged_user_subscribeInside_header_top'}
#
#
# URL:  https://elpais.com/subscriptions/#/profile
# Contenido:  ['Mis datos']
# Atributos: {'href': 'https://elpais.com/subscriptions/#/profile'}
#
#
# URL:  https://elpais.com/subscriptions/#/manage
# Contenido:  ['Mi suscripción']
# Atributos: {'href': 'https://elpais.com/subscriptions/#/manage'}
#
#
# URL:  https://plus.elpais.com/perfil/newsletters/
# Contenido:  ['Newsletters']
# Atributos: {'href': 'https://plus.elpais.com/perfil/newsletters/'}
#
#
# URL:  https://elpais.com/suscripciones/elpaismas.html
# Contenido:  ['Experiencias para mí']
# Atributos: {'href': 'https://elpais.com/suscripciones/elpaismas.html'}
#
#
# URL:  https://plus.elpais.com/perfil/actividad/
# Contenido:  ['Mi actividad']
# Atributos: {'href': 'https://plus.elpais.com/perfil/actividad/'}
#
#
# URL:  https://plus.elpais.com/perfil/baja/
# Contenido:  ['Derechos y baja']
# Atributos: {'href': 'https://plus.elpais.com/perfil/baja/'}
#
#
# URL:  https://elpais.com/subscriptions/#/sign-out?backURL=https%3A%2F%2Felpais.com%2Fhomepage
# Contenido:  ['desconectar']
# Atributos: {'class': ['button', '|', 'flex', 'button', 'button_logout', 'text_transform_none', 'no_hover', 'align_items_center', 'border-box'], 'href': 'https://elpais.com/subscriptions/#/sign-out?backURL=https%3A%2F%2Felpais.com%2Fhomepage'}
#
#
# URL:  https://elpais.com
# Contenido:  [<div class="logo primary_claim"></div>]
# Atributos: {'href': 'https://elpais.com', 'class': []}
#
#
# URL:  https://suscripciones.elpais.com/?prm=suscrip_cabecera_ep.com&prod=SUSDIG&o=boton_cab&backURL=NaN#/campaign
# Contenido:  ['suscríbete']
# Atributos: {'class': ['button', 'button_primary', '|', 'flex', 'subscribe', '|', 'relative', 'padding_left_sm', 'align_items_center', 'no_hover', 'logged_user_subscribeOutside', 'bold', 'whitespace_nowrap', 'align_items_center', 'border-box'], 'href': 'https://suscripciones.elpais.com/?prm=suscrip_cabecera_ep.com&prod=SUSDIG&o=boton_cab&backURL=NaN#/campaign', 'id': ''}
#
#
# URL:  https://elpais.com/subscriptions/#/sign-in?prod=REG&o=CABEP&backURL=https%3A%2F%2Felpais.com%2Fhomepage
# Contenido:  [<span class="user_initials | border_1 border_solid border_round flex justify_center align_items_center border-box"><svg class="icon_portal_login_subscriber | user_icon | relative color_gray_light" viewbox="0 0 26 23"><g fill="none" fill-rule="evenodd" stroke="none" stroke-width="1"><g fill="currentColor" transform="translate(-316.000000, -7.000000)"><g transform="translate(282.000000, 7.000000)"><g transform="translate(34.000000, 0.000000)"><path d="M-2.82440737e-13,13.1611427 C-2.82440737e-13,5.90393376 5.83164706,0 13,0 C20.1683529,0 26,5.90393376 26,13.1611427 C26,17.0718085 24.304902,20.58764 21.6212941,23 C21.4714118,22.895227 21.3205098,22.8012926 21.1660392,22.7228418 L16.8495294,20.5380921 C16.4620784,20.3419653 16.221451,19.9476472 16.221451,19.5094585 L16.221451,17.9832821 C16.3213725,17.8583803 16.426902,17.7169625 16.536,17.5616094 C17.0947451,16.7626506 17.5428627,15.8738864 17.8696471,14.91751 C18.5155686,14.6068039 18.9325882,13.9554563 18.9325882,13.2199807 L18.9325882,11.3903238 C18.9325882,10.942845 18.7704706,10.5087853 18.4803922,10.1676279 L18.4803922,7.75888069 C18.506902,7.4904966 18.6007059,5.97928775 17.5204314,4.732334 C16.5808627,3.6464107 15.0601176,3.09673945 13,3.09673945 C10.9398824,3.09673945 9.41913725,3.6464107 8.47956863,4.73181788 C7.39929412,5.97877163 7.49309804,7.49101272 7.51960784,7.75836456 L7.51960784,10.1671117 C7.23003922,10.5082692 7.06741176,10.9423288 7.06741176,11.3898077 L7.06741176,13.2194646 C7.06741176,13.7877163 7.3192549,14.3177748 7.75054902,14.6754482 C8.1634902,16.3131073 9.01333333,17.5528353 9.32737255,17.9729596 L9.32737255,19.4666203 C9.32737255,19.8877769 9.1005098,20.2748693 8.73498039,20.4771896 L4.70396078,22.7032291 C4.5754902,22.773938 4.44803922,22.8565177 4.32058824,22.9489038 C1.67011765,20.537576 -2.82440737e-13,17.0434217 -2.82440737e-13,13.1611427 Z"></path></g></g></g></g></svg></span>, <span class="user_login | hidden_mobile uppercase whitespace_nowrap">Iniciar sesión</span>]
# Atributos: {'href': 'https://elpais.com/subscriptions/#/sign-in?prod=REG&o=CABEP&backURL=https%3A%2F%2Felpais.com%2Fhomepage', 'class': ['user_profile', '|', 'bold', 'flex', 'height_full', 'width_full', 'z_index_50', 'align_items_center', 'border-box'], 'id': 'not_logged_user_'}
#
#
# URL:  https://elpais.com/landing_oferta/#/campaignprod=SUSDIG&o=login_ep&backURL=NaN#/campaign
# Contenido:  ['suscríbete por 1€']
# Atributos: {'href': 'https://elpais.com/landing_oferta/#/campaignprod=SUSDIG&o=login_ep&backURL=NaN#/campaign', 'class': ['button', 'button__offer', '|', 'flex_inline', 'margin_vertical', 'bold', 'color_white', 'uppercase', 'no_hover'], 'id': 'logged_user_subscribeInside_header_middle'}
#
#
# URL:  https://elpais.com/subscriptions/#/profile
# Contenido:  ['Mis datos']
# Atributos: {'href': 'https://elpais.com/subscriptions/#/profile'}
#
#
# URL:  https://elpais.com/subscriptions/#/manage
# Contenido:  ['Mi suscripción']
# Atributos: {'href': 'https://elpais.com/subscriptions/#/manage'}
#
#
# URL:  https://plus.elpais.com/perfil/newsletters/
# Contenido:  ['Newsletters']
# Atributos: {'href': 'https://plus.elpais.com/perfil/newsletters/'}
#
#
# URL:  https://elpais.com/suscripciones/elpaismas.html
# Contenido:  ['Experiencias para mí']
# Atributos: {'href': 'https://elpais.com/suscripciones/elpaismas.html'}
#
#
# URL:  https://plus.elpais.com/perfil/actividad/
# Contenido:  ['Mi actividad']
# Atributos: {'href': 'https://plus.elpais.com/perfil/actividad/'}
#
#
# URL:  https://plus.elpais.com/perfil/baja/
# Contenido:  ['Derechos y baja']
# Atributos: {'href': 'https://plus.elpais.com/perfil/baja/'}
#
#
# URL:  https://elpais.com/subscriptions/#/sign-out?backURL=https%3A%2F%2Felpais.com%2Fhomepage
# Contenido:  ['desconectar']
# Atributos: {'class': ['button', '|', 'flex', 'button', 'button_logout', 'text_transform_none', 'no_hover', 'align_items_center', 'border-box'], 'href': 'https://elpais.com/subscriptions/#/sign-out?backURL=https%3A%2F%2Felpais.com%2Fhomepage'}
#
#
# URL:  https://suscripciones.elpais.com/?prm=suscrip_cabecera_ep.com&prod=SUSDIG&o=boton_cab&backURL=NaN#/campaign
# Contenido:  ['suscríbete']
# Atributos: {'class': ['button', 'button_primary', '|', 'flex', 'subscribe', '|', 'align_items_center', 'no_hover', 'bold', 'whitespace_nowrap', 'align_items_center', 'border-box'], 'href': 'https://suscripciones.elpais.com/?prm=suscrip_cabecera_ep.com&prod=SUSDIG&o=boton_cab&backURL=NaN#/campaign', 'id': 'f0feSvZw1PwDPj'}
#
#
# URL:  /espana/2021-03-23/la-ley-electoral-de-madrid-obliga-a-pablo-iglesias-a-adelantar-su-salida-del-gobierno-antes-del-31-de-marzo.html
# Contenido:  [<img alt="El vicepresidente segundo del Gobierno, Pablo Iglesias, interviene durante la sesión de control al Ejecutivo celebrada en el Senado." class="block width_full breakout_mobile" loading="eager" src="https://imagenes.elpais.com/resizer/iPeLEzXYS2cQb86oYMxTkSHqIic=/62x34/cloudfront-eu-central-1.images.arcpublishing.com/prisa/DXU5MTJGHPKQ2ON3GHFOV2V7QI.jpg"/>]
# Atributos: {'href': '/espana/2021-03-23/la-ley-electoral-de-madrid-obliga-a-pablo-iglesias-a-adelantar-su-salida-del-gobierno-antes-del-31-de-marzo.html', 'class': ['image_link', '|', 'width_full', 'block', 'relative']}
#
#
# URL:  /espana/2021-03-23/la-ley-electoral-de-madrid-obliga-a-pablo-iglesias-a-adelantar-su-salida-del-gobierno-antes-del-31-de-marzo.html
#
#
# URL:  https://elpais.com/autor/francisco-hugo-gutierrez-iglesias/
# Contenido:  ['Hugo Gutiérrez']
# Atributos: {'href': 'https://elpais.com/autor/francisco-hugo-gutierrez-iglesias/', 'class': ['author', '|']}
#
#
# URL:  /economia/2021-03-23/los-sindicatos-de-bankia-amenazan-con-movilizaciones-por-la-fusion-con-caixabank-si-hay-despidos-forzados.html
# Contenido:  ['Los sindicatos de Bankia amenazan con movilizaciones por la fusión con CaixaBank si hay despidos']
# Atributos: {'href': '/economia/2021-03-23/los-sindicatos-de-bankia-amenazan-con-movilizaciones-por-la-fusion-con-caixabank-si-hay-despidos-forzados.html', 'class': ['c_r_s_h', 'related_story_headline']}
#
#
# URL:  /sociedad/2021-03-23/la-voz-de-rocio-carrasco-y-el-eco-de-la-violencia-machista.html
# Contenido:  ['La voz de Rocío Carrasco y el eco de la violencia machista']
# Atributos: {'href': '/sociedad/2021-03-23/la-voz-de-rocio-carrasco-y-el-eco-de-la-violencia-machista.html'}
#
#
# URL:  https://elpais.com/autor/pilar-alvarez/
# Contenido:  ['Pilar Álvarez']
# Atributos: {'href': 'https://elpais.com/autor/pilar-alvarez/', 'class': ['author', '|']}
#
#
# URL:  /cultura/2021-03-23/los-arqueologos-espanoles-se-hartan-de-la-destruccion-del-patrimonio-cultural.html
# Contenido:  ['Los arqueólogos españoles se hartan de la destrucción del patrimonio cultural']
# Atributos: {'href': '/cultura/2021-03-23/los-arqueologos-espanoles-se-hartan-de-la-destruccion-del-patrimonio-cultural.html'}
#
#
# URL:  https://elpais.com/autor/manuel-morales/
# Contenido:  ['Manuel Morales']
# Atributos: {'href': 'https://elpais.com/autor/manuel-morales/', 'class': ['author', '|']}
#
#
# URL:  https://elpais.com/elpais/planeta_futuro.html
# Contenido:  [<span>PLANETA FUTURO</span>]
# Atributos: {'class': ['k', 'kicker', '|', 'uppercase'], 'href': 'https://elpais.com/elpais/planeta_futuro.html'}
#
#
# URL:  /planeta-futuro/2021-03-23/lo-que-paso-en-la-sabana-cuando-se-vacio-de-turistas.html
# Contenido:  ['Lo que pasó en la sabana cuando se vació de turistas']
# Atributos: {'href': '/planeta-futuro/2021-03-23/lo-que-paso-en-la-sabana-cuando-se-vacio-de-turistas.html'}
#
#
# URL:  https://elpais.com/autor/analia-iglesias/
# Contenido:  ['Analía Iglesias']
# Atributos: {'href': 'https://elpais.com/autor/analia-iglesias/', 'class': ['author', '|']}
#
#
# URL:  /deportes/lo-inteligente-es-seguir/2021-03-23/laia-palau-un-equipo-de-baloncesto-es-una-escuela-de-sororidad.html
# Contenido:  ['Laia Palau:\xa0“Un equipo es una escuela de sororidad”. El único deporte que practican más de 100.000 mujeres\n']
# Atributos: {'href': '/deportes/lo-inteligente-es-seguir/2021-03-23/laia-palau-un-equipo-de-baloncesto-es-una-escuela-de-sororidad.html'}
#
#
# URL:  https://elpais.com/autor/alejandro-martin-rodriguez/
# Contenido:  ['Alejandro Martín']
# Atributos: {'href': 'https://elpais.com/autor/alejandro-martin-rodriguez/', 'class': ['author', '|']}
#
#
# URL:  https://elpais.com/opinion/
# Contenido:  [<span>Opinión</span>]
# Atributos: {'class': ['color_black', 'title'], 'href': 'https://elpais.com/opinion/'}
#
#
# URL:  https://elpais.com/opinion/editoriales/
# Contenido:  ['Editoriales']
# Atributos: {'class': ['color_black'], 'href': 'https://elpais.com/opinion/editoriales/'}
#
#
# URL:  https://elpais.com/opinion/tribunas/
# Contenido:  ['Tribunas']
# Atributos: {'class': ['color_black'], 'href': 'https://elpais.com/opinion/tribunas/'}
#
#
# URL:  https://elpais.com/opinion/columnas/
# Contenido:  ['Columnas']
# Atributos: {'class': ['color_black'], 'href': 'https://elpais.com/opinion/columnas/'}
#
#
# URL:  https://elpais.com/noticias/defensor-lector/
# Contenido:  ['Defensor del Lector']
# Atributos: {'class': ['color_black'], 'href': 'https://elpais.com/noticias/defensor-lector/'}
#
#
# URL:  https://elpais.com/opinion/editoriales
# Contenido:  [<span>EDITORIAL</span>]
# Atributos: {'class': ['k', 'kicker', '|', 'uppercase', 'color_gray_ultra_dark', 'block'], 'href': 'https://elpais.com/opinion/editoriales'}
#
#
# URL:  /opinion/2021-03-23/radicalismo-en-la-sombra-en-cataluna.html
# Contenido:  ['Radicalismo en la sombra en Cataluña']
# Atributos: {'href': '/opinion/2021-03-23/radicalismo-en-la-sombra-en-cataluna.html', 'rel': [], 'target': ''}
#
#
# URL:  https://elpais.com/opinion/tribunas/
# Contenido:  [<span>Artículo bajo registro</span>]
# Atributos: {'class': ['k', 'kicker', '|', 'kicker_registertoread', '|', 'uppercase', 'color_gray_ultra_dark', 'block'], 'href': 'https://elpais.com/opinion/tribunas/'}
#
#
# URL:  /opinion/2021-03-23/un-pacto-verde-mundial.html
# Contenido:  ['Un pacto verde mundial']
# Atributos: {'href': '/opinion/2021-03-23/un-pacto-verde-mundial.html', 'rel': [], 'target': ''}
#
#
# URL:  https://elpais.com/autor/ursula-gertrud-von-der-leyen/
# Contenido:  ['Ursula von der Leyen']
# Atributos: {'href': 'https://elpais.com/autor/ursula-gertrud-von-der-leyen/', 'class': ['author', '|']}
#
#
# URL:  https://elpais.com/autor/werner-hoyer/
# Contenido:  ['Werner Hoyer']
# Atributos: {'href': 'https://elpais.com/autor/werner-hoyer/', 'class': ['author', '|']}
#
#
# URL:  https://elpais.com/opinion/columnas/
# Contenido:  [<span>Artículo bajo registro</span>]
# Atributos: {'class': ['k', 'kicker', '|', 'kicker_registertoread', '|', 'uppercase', 'color_gray_ultra_dark', 'block'], 'href': 'https://elpais.com/opinion/columnas/'}
#
#
# URL:  /opinion/2021-03-22/de-viaje.html
# Contenido:  ['De viaje']
# Atributos: {'href': '/opinion/2021-03-22/de-viaje.html', 'rel': [], 'target': ''}
#
#
# URL:  https://elpais.com/autor/felix-de-azua/
# Contenido:  ['Félix de Azúa']
# Atributos: {'href': 'https://elpais.com/autor/felix-de-azua/', 'class': ['author', '|']}
#
#
# URL:  https://elpais.com/noticias/elecciones-comunidad-madrid/
# Contenido:  [<span>                                                                                                                     . </span>]
# Atributos: {'class': ['k', 'kicker', '|', 'uppercase', 'color_gray_ultra_dark', 'block'], 'href': 'https://elpais.com/noticias/elecciones-comunidad-madrid/'}
#
#
# URL:  /espana/2021-03-23/un-gobierno-excepcional-ni-mas-impuestos-ni-mas-extremismos.html
# Contenido:  ['Un Gobierno excepcional: ni más impuestos ni más extremismos']
# Atributos: {'href': '/espana/2021-03-23/un-gobierno-excepcional-ni-mas-impuestos-ni-mas-extremismos.html', 'rel': [], 'target': ''}
#
#
# URL:  https://elpais.com/autor/angel-gabilondo/
# Contenido:  ['Ángel Gabilondo']
# Atributos: {'href': 'https://elpais.com/autor/angel-gabilondo/', 'class': ['author', '|']}
#
#
# URL:  https://elpais.com/autor/inigo-dominguez-gabina/
# Contenido:  [<span>Artículo bajo registro</span>]
# Atributos: {'class': ['k', 'kicker', '|', 'kicker_registertoread', '|', 'uppercase', 'color_gray_ultra_dark', 'block'], 'href': 'https://elpais.com/autor/inigo-dominguez-gabina/'}
#
#
# URL:  /ideas/2021-03-19/ich-bin-ein-madrileno.html
# Contenido:  ['“Ich bin ein Madrileño”']
# Atributos: {'href': '/ideas/2021-03-19/ich-bin-ein-madrileno.html', 'rel': [], 'target': ''}
#
#
# URL:  https://elpais.com/autor/inigo-dominguez-gabina/
# Contenido:  ['Iñigo Domínguez']
# Atributos: {'href': 'https://elpais.com/autor/inigo-dominguez-gabina/', 'class': ['author', '|']}
#
#
# URL:  https://elpais.com/noticias/derechos-humanos/
# Contenido:  [<span>Artículo bajo registro</span>]
# Atributos: {'class': ['k', 'kicker', '|', 'kicker_registertoread', '|', 'uppercase'], 'href': 'https://elpais.com/noticias/derechos-humanos/'}
#
#
# URL:  /cultura/2021-03-22/ai-weiwei-occidente-esta-perdiendo-sus-valores.html
# Contenido:  ['Ai Weiwei: “Occidente está perdiendo sus valores”']
# Atributos: {'href': '/cultura/2021-03-22/ai-weiwei-occidente-esta-perdiendo-sus-valores.html'}
#
#
# URL:  https://elpais.com/autor/jamil-chade/
# Contenido:  ['Jamil Chade']
# Atributos: {'href': 'https://elpais.com/autor/jamil-chade/', 'class': ['author', '|']}
#
#
# URL:  https://elpais.com/internacional/
# Contenido:  [<span>INTERNACIONAL</span>]
# Atributos: {'class': ['k', 'kicker', '|', 'uppercase'], 'href': 'https://elpais.com/internacional/'}
#
#
# URL:  /mexico/2021-03-22/la-esperanza-en-biden-termina-en-la-frontera.html
# Contenido:  ['La esperanza en Biden termina en la frontera']
# Atributos: {'href': '/mexico/2021-03-22/la-esperanza-en-biden-termina-en-la-frontera.html'}
#
#
# URL:  https://elpais.com/autor/jacobo-garcia-garcia/
# Contenido:  ['Jacobo García']
# Atributos: {'href': 'https://elpais.com/autor/jacobo-garcia-garcia/', 'class': ['author', '|']}
#
#
# URL:  https://elpais.com/eps/
# Contenido:  [<span>EL PAÍS SEMANAL</span>]
# Atributos: {'class': ['k', 'kicker', '|', 'uppercase'], 'href': 'https://elpais.com/eps/'}
#
#
# URL:  /elpais/2021/03/17/album/1616006746_422694.html
# Contenido:  ['Reinas de Nueva York']
# Atributos: {'href': '/elpais/2021/03/17/album/1616006746_422694.html'}
#
#
# URL:  https://elpais.com/autor/el-pais-semanal/
# Contenido:  ['CAMILA FÁLQUEZ / HERIN CHOI / CÉSAR VALLEJO']
# Atributos: {'href': 'https://elpais.com/autor/el-pais-semanal/', 'class': ['author', '|']}
#
#
# URL:  https://elpais.com/noticias/propiedad-tierra/
# Contenido:  [<span>Negocios</span>]
# Atributos: {'class': ['k', 'kicker', '|', 'uppercase'], 'href': 'https://elpais.com/noticias/propiedad-tierra/'}
#
#
# URL:  /economia/2021-03-21/los-nuevos-terratenientes-de-espana.html
# Contenido:  ['Los nuevos terratenientes de España']
# Atributos: {'href': '/economia/2021-03-21/los-nuevos-terratenientes-de-espana.html'}
#
#
# URL:  https://elpais.com/autor/maria-fernandez/
# Contenido:  ['María Fernández']
# Atributos: {'href': 'https://elpais.com/autor/maria-fernandez/', 'class': ['author', '|']}
#
#
# URL:  https://suscripciones.elpais.com/para-conocer/
# Contenido:  [<span>Suscríbete a los hechos</span>]
# Atributos: {'class': ['color_black', 'title'], 'href': 'https://suscripciones.elpais.com/para-conocer/'}
#
#
# URL:  /sociedad/modelo-de-suscripcion/2021-03-17/inigo-dominguez-el-que-escribe-y-el-que-lo-lee-son-dos-personas-solas-en-el-mundo-que-se-estan-comunicando.html
# Contenido:  ['Íñigo Domínguez: “El que escribe y el que lo lee son dos personas solas en el mundo que se están comunicando”']
# Atributos: {'href': '/sociedad/modelo-de-suscripcion/2021-03-17/inigo-dominguez-el-que-escribe-y-el-que-lo-lee-son-dos-personas-solas-en-el-mundo-que-se-estan-comunicando.html'}
#
#
# URL:  https://apiservices.krxd.net/click_tracker/track?kx_event_uid=N6MkIrTq&kx_distribuidor=redaccion&kx_origen=elpais&kx_disciplina=editorial&kx_formato=friso&kx_creatividad=linkpieimagensuscripcion&kx_formato_creatividad=friso_linkpieimagensuscripcion&kx_landing_destino=ES&clk=https://elpais.com/landing_oferta/#/campaign?cid=ZWxwYWlzX3JlZGFjY2lvbl9lcG1hc19lZGl0b3JpYWxfZnJpc29fbGlua3BpZWltYWdlbnN1c2NyaXBjaW9uX0VT
# Contenido:  ['Suscríbete para leer sin límites, conocer y ser parte por un euro el primer mes']
# Atributos: {'href': 'https://apiservices.krxd.net/click_tracker/track?kx_event_uid=N6MkIrTq&kx_distribuidor=redaccion&kx_origen=elpais&kx_disciplina=editorial&kx_formato=friso&kx_creatividad=linkpieimagensuscripcion&kx_formato_creatividad=friso_linkpieimagensuscripcion&kx_landing_destino=ES&clk=https://elpais.com/landing_oferta/#/campaign?cid=ZWxwYWlzX3JlZGFjY2lvbl9lcG1hc19lZGl0b3JpYWxfZnJpc29fbGlua3BpZWltYWdlbnN1c2NyaXBjaW9uX0VT'}
#
#
# URL:  https://suscripciones.elpais.com/para-conocer/conversaciones/juan-echanove/
# Contenido:  ['Juan Echanove: “Cuando los medios pierden independencia, pierden su esencia”']
# Atributos: {'href': 'https://suscripciones.elpais.com/para-conocer/conversaciones/juan-echanove/'}
#
#
# URL:  https://elpais.com/noticias/covid-19/
# Contenido:  [<span>LA CRISIS DEL CORONAVIRUS</span>]
# Atributos: {'class': ['color_black', 'title'], 'href': 'https://elpais.com/noticias/covid-19/'}
#
#
# URL:  https://elpais.com/especiales/2020/coronavirus-covid-19/fases-desescalada/
# Contenido:  ['Buscador de restricciones']
# Atributos: {'class': ['color_black'], 'href': 'https://elpais.com/especiales/2020/coronavirus-covid-19/fases-desescalada/'}
#
#
# URL:  https://elpais.com/sociedad/2020/03/30/actualidad/1585589827_546714.html
# Contenido:  ['Casos confirmados']
# Atributos: {'class': ['color_black'], 'href': 'https://elpais.com/sociedad/2020/03/30/actualidad/1585589827_546714.html'}
#
#
# URL:  https://elpais.com/especiales/2020/coronavirus-covid-19/
# Contenido:  ['Preguntas y respuestas']
# Atributos: {'class': ['color_black'], 'href': 'https://elpais.com/especiales/2020/coronavirus-covid-19/'}
#
#
# URL:  https://elpais.com/sociedad/2020/03/16/actualidad/1584360628_538486.html
# Contenido:  ['Mapa de expansión']
# Atributos: {'class': ['color_black'], 'href': 'https://elpais.com/sociedad/2020/03/16/actualidad/1584360628_538486.html'}
#
#
# URL:  /economia/2021-03-23/las-autonomias-del-pp-piden-una-reunion-urgente-a-hacienda-para-modificar-el-decreto-de-ayudas-directas-a-empresas.html
# Contenido:  ['Las autonomías del PP piden una reunión urgente a Hacienda para modificar el decreto de ayudas directas a empresas']
# Atributos: {'href': '/economia/2021-03-23/las-autonomias-del-pp-piden-una-reunion-urgente-a-hacienda-para-modificar-el-decreto-de-ayudas-directas-a-empresas.html'}
#
#
# URL:  https://elpais.com/autor/laura-delle-femmine/
# Contenido:  ['Laura Delle Femmine']
# Atributos: {'href': 'https://elpais.com/autor/laura-delle-femmine/', 'class': ['author', '|']}
#
#
# URL:  /economia/2021-03-23/las-pernoctaciones-hoteleras-en-espana-cayeron-un-86-en-febrero.html
# Contenido:  ['Las pernoctaciones hoteleras en España cayeron un 86% en febrero y acumulan un año de retrocesos']
# Atributos: {'href': '/economia/2021-03-23/las-pernoctaciones-hoteleras-en-espana-cayeron-un-86-en-febrero.html'}
#
#
# URL:  /economia/2021-03-23/el-comercio-espera-crecer-un-4-este-ano-si-en-verano-se-permite-la-movilidad-entre-comunidades.html
# Contenido:  ['El comercio espera crecer un 4% este año si en verano se permite la movilidad entre comunidades']
# Atributos: {'href': '/economia/2021-03-23/el-comercio-espera-crecer-un-4-este-ano-si-en-verano-se-permite-la-movilidad-entre-comunidades.html'}
#
#
# URL:  https://elpais.com/ideas/
# Contenido:  [<span>Artículo bajo registro</span>]
# Atributos: {'class': ['k', 'kicker', '|', 'kicker_registertoread', '|', 'uppercase'], 'href': 'https://elpais.com/ideas/'}
#
#
# URL:  /ideas/2021-03-23/tras-la-covid-19-celebremos-el-dia-de-la-interdependencia.html
# Contenido:  ['Tras la covid-19, celebremos el Día de la Interdependencia']
# Atributos: {'href': '/ideas/2021-03-23/tras-la-covid-19-celebremos-el-dia-de-la-interdependencia.html'}
#
#
# URL:  https://elpais.com/autor/adela-cortina/
# Contenido:  ['Adela Cortina']
# Atributos: {'href': 'https://elpais.com/autor/adela-cortina/', 'class': ['author', '|']}
#
#
# URL:  /espana/madrid/2021-03-23/15-cientificos-rebaten-un-escrito-del-viceconsejero-de-sanidad-de-madrid-en-the-lancet.html
# Contenido:  ['15 científicos rebaten un escrito del viceconsejero de Sanidad de Madrid en ‘The Lancet’']
399-.155l4-5.186c.52-.67 1.646-.673 2.167 0l4.065 5.256c.008.012.218.082.335.082h.4a.805.805 0 0 0 .397-.152l4-5.187c.26-.336.66-.534 1.083-.534h.001c.423 0 .823.198 1.082.534l3.386 4.387V18.19c-.002-.405-.077-4.107-1.927-7.766a1.088 1.088 0 0 1-.055-.097c-1.127-2.197-2.679-3.946-4.615-5.195-2.431-1.568-5.492-2.361-9.098-2.361-3.609 0-6.67.793-9.1 2.362C7.396 6.381 5.844 8.13 4.72 10.326c-1.918 3.733-1.974 7.452-1.974 7.864V38.25l3.106-4.046a1.38 1.38 0 0 1 1.082-.536h.003c.423 0 .822.197 1.082.533l4.032 5.204zM1.986 42.34c-.947 0-1.931-.712-1.98-2.077C0 40.158 0 39.98 0 39.788V18.19c0-.481.064-4.823 2.28-9.136 1.347-2.632 3.222-4.74 5.575-6.257C10.733.941 14.293 0 18.435 0c4.139 0 7.698.941 10.58 2.797 2.317 1.498 4.173 3.568 5.52 6.157.02.03.04.065.059.1 2.145 4.178 2.278 8.337 2.284 9.129v21.602c0 1.75-1.103 2.548-2.126 2.548-.816 0-1.515-.54-1.957-.992-.024-.024-.091-.103-.113-.129L29.66 37.3l-3 3.883a1.678 1.678 0 0 1-.113.128c-.6.613-1.522.992-2.367.992h-.4c-.845 0-1.766-.38-2.346-.972a2.652 2.652 0 0 1-.156-.175L18.3 37.3l-3.004 3.885a1.066 1.066 0 0 1-.112.127c-.6.612-1.523.992-2.368.992h-.396c-.842 0-1.761-.378-2.345-.967a1.194 1.194 0 0 1-.11-.127L6.94 37.308 3.95 41.2a1.063 1.063 0 0 1-.09.104c-.547.558-1.02 1.037-1.873 1.037z" fill-rule="evenodd"></path></svg>]
# Atributos: {'class': ['button', 'button_primary', '|', 'flex', 'justify_center', 'color_white', 'margin_vertical', 'align_items_center', 'border-box'], 'href': 'https://juegos.elpais.com/?arkpromo=HomeEP_ServiciosLink'}
#
#
# URL:  https://cincodias.elpais.com/herramientas/calculadora-sueldo-neto/
# ...
#
#
# URL:  https://elpais.com/planeta-futuro/
# Contenido:  [<span class="block text_indent">PLANETA FUTURO</span>]
# Atributos: {'class': ['k', 'kicker', '|', 'kicker_planetafuturo_white', 'width_full', '|', 'uppercase'], 'href': 'https://elpais.com/planeta-futuro/'}
#
#
# URL:  /elpais/2021/03/18/album/1616078791_837322.html
# Contenido:  ['Nana y el árbol que tenía sed']
# Atributos: {'href': '/elpais/2021/03/18/album/1616078791_837322.html'}
#
#
# URL:  https://elpais.com/eps/
# Contenido:  [<span class="block text_indent">EL PAÍS SEMANAL</span>]
# Atributos: {'class': ['k', 'kicker', '|', 'kicker_eps_white', 'width_full', '|', 'uppercase'], 'href': 'https://elpais.com/eps/'}
#
#
# URL:  /eps/2021-03-21/aceleracionismo-la-nueva-amenaza-del-supremacismo-blanco.html
# Contenido:  ['Aceleracionismo, la nueva amenaza del supremacismo blanco']
# Atributos: {'href': '/eps/2021-03-21/aceleracionismo-la-nueva-amenaza-del-supremacismo-blanco.html'}
#
#
# URL:  https://elpais.com/economia/negocios/
# Contenido:  [<span class="block text_indent">NEGOCIOS</span>]
# Atributos: {'class': ['k', 'kicker', '|', 'kicker_negocios_white', 'width_full', '|', 'uppercase'], 'href': 'https://elpais.com/economia/negocios/'}
#
#
# URL:  /economia/2021-03-20/los-ricos-latinoamericanos-se-pelean-por-los-pisos-mas-exclusivos-de-la-milla-de-oro-de-madrid.html
# Contenido:  ['Los ricos latinoamericanos se pelean por los pisos más exclusivos de la Milla de Oro de Madrid']
# Atributos: {'href': '/economia/2021-03-20/los-ricos-latinoamericanos-se-pelean-por-los-pisos-mas-exclusivos-de-la-milla-de-oro-de-madrid.html'}
#
#
# URL:  https://elviajero.elpais.com/
# Contenido:  [<span class="block text_indent">Artículo bajo registro</span>]
# Atributos: {'class': ['k', 'kicker', '|', 'kicker_elviajero_white', 'width_full', '|', 'uppercase'], 'href': 'https://elviajero.elpais.com/'}
#
#
# URL:  https://elpais.com/elviajero/2021/03/18/actualidad/1616073455_078748.html
# Contenido:  ['Triángulo cultural asturiano']
# Atributos: {'href': 'https://elpais.com/elviajero/2021/03/18/actualidad/1616073455_078748.html'}
#
#
# URL:  https://elpais.com/babelia/
# Contenido:  [<span class="block text_indent">Artículo bajo registro</span>]
# Atributos: {'class': ['k', 'kicker', '|', 'kicker_babelia_white', 'width_full', '|', 'uppercase'], 'href': 'https://elpais.com/babelia/'}
#
#
# URL:  /babelia/2021-03-20/andre-gide-ante-un-espejo-de-3000-paginas.html
# Contenido:  ['André Gide ante un espejo de 3.000 páginas']
# Atributos: {'href': '/babelia/2021-03-20/andre-gide-ante-un-espejo-de-3000-paginas.html'}
#
#
# URL:  https://elpais.com/ideas/
# Contenido:  [<span class="block text_indent">Artículo bajo registro</span>]
# Atributos: {'class': ['k', 'kicker', '|', 'kicker_ideas_white', 'width_full', '|', 'uppercase'], 'href': 'https://elpais.com/ideas/'}
#
#
# URL:  /ideas/2021-03-21/dolors-sabater-una-activista-acrata-en-la-cup.html
# Contenido:  ['Dolors Sabater, una activista ácrata en la CUP']
# Atributos: {'href': '/ideas/2021-03-21/dolors-sabater-una-activista-acrata-en-la-cup.html'}
#
#
# URL:  https://elcomidista.elpais.com/
# Contenido:  [<span class="block text_indent">EL COMIDISTA</span>]
# Atributos: {'class': ['k', 'kicker', '|', 'kicker_elcomidista_white', 'width_full', '|', 'uppercase'], 'href': 'https://elcomidista.elpais.com/'}
#
#
# URL:  https://elpais.com/elcomidista/2021/03/09/articulo/1615294533_679489.html
# Contenido:  ["Las quejas de los lectores: el 'coulant' de chocolate que pierde mantequilla"]
# Atributos: {'href': 'https://elpais.com/elcomidista/2021/03/09/articulo/1615294533_679489.html'}
#
#
# URL:  https://elpais.com/icon/
# Contenido:  [<span class="block text_indent">ICON</span>]
# Atributos: {'class': ['k', 'kicker', '|', 'kicker_icon_white', 'width_full', '|', 'uppercase'], 'href': 'https://elpais.com/icon/'}
#
#
# URL:  /icon/2021-03-19/ha-llegado-el-momento-de-tirar-nuestra-coleccion-de-cds-o-resucitaran-como-los-vinilos.html
# Contenido:  ['¿Ha llegado el momento de tirar la colección de discos o resucitarán como los vinilos?']
# Atributos: {'href': '/icon/2021-03-19/ha-llegado-el-momento-de-tirar-nuestra-coleccion-de-cds-o-resucitaran-como-los-vinilos.html'}
#
#
# URL:  https://elpais.com/elpais/icon_design.html?por=mosaico
# Contenido:  [<span class="block text_indent">ICON DESIGN</span>]
# Atributos: {'class': ['k', 'kicker', '|', 'kicker_icondesign_white', 'width_full', '|', 'uppercase'], 'href': 'https://elpais.com/elpais/icon_design.html?por=mosaico'}
#
#
# URL:  /icon-design/arquitectura/2021-03-19/como-el-sueno-de-un-arquitecto-y-la-locura-de-un-cliente-acabaron-transformando-una-iglesia-en-ruinas-en-una-casa-de-diseno.html
# Contenido:  ['Cómo el sueño de un arquitecto y la “locura” de un cliente acabaron transformando una iglesia en ruinas\xa0']
# Atributos: {'href': '/icon-design/arquitectura/2021-03-19/como-el-sueno-de-un-arquitecto-y-la-locura-de-un-cliente-acabaron-transformando-una-iglesia-en-ruinas-en-una-casa-de-diseno.html'}
#
#
# URL:  https://smoda.elpais.com/
# Contenido:  [<span class="block text_indent">SMODA</span>]
# Atributos: {'class': ['k', 'kicker', '|', 'kicker_smoda_white', 'width_full', '|', 'uppercase'], 'href': 'https://smoda.elpais.com/'}
#
#
# URL:  https://smoda.elpais.com/celebrities/soleil-moon-frye-punky-brewster-documental-kid-90/
# Contenido:  ['La estrella infantil Punky Brewster habla de su tormentosa adolescencia']
# Atributos: {'href': 'https://smoda.elpais.com/celebrities/soleil-moon-frye-punky-brewster-documental-kid-90/'}
#
#
# URL:  http://cincodias.com/?por=mosaico
# Contenido:  [<span>Cinco Días</span>]
# Atributos: {'class': ['k', 'kicker', '|', 'kicker_cincodias_white', 'text_indent', 'width_full', '|', 'uppercase', 'color_gray_ultra_dark'], 'href': 'http://cincodias.com/?por=mosaico'}
#
#
# URL:  https://cincodias.elpais.com/cincodias/2021/03/17/companias/1615978777_392526.html
# Contenido:  ['¿Un coche eléctrico es más caro que uno de gasolina? Depende']
# Atributos: {'href': 'https://cincodias.elpais.com/cincodias/2021/03/17/companias/1615978777_392526.html', 'rel': [], 'target': ''}
#
#
# URL:  http://www.huffingtonpost.es/?por=mosaico
# Contenido:  [<span>Huffington Post</span>]
# Atributos: {'class': ['k', 'kicker', '|', 'kicker_huffpost_white', 'text_indent', 'width_full', '|', 'uppercase', 'color_gray_ultra_dark'], 'href': 'http://www.huffingtonpost.es/?por=mosaico'}
#
#
# URL:  https://www.huffingtonpost.es/entry/ayuso-dice-que-los-turistas-vienen-a-ver-museos-y-mamen-mendizabal-se-pasa-twitter-con-su-reaccion_es_6059f57fc5b6f12839d7b570
# Contenido:  ['Ayuso dice que los turistas vienen a ver museos y Mamen Mendizábal se pasa Twitter con su reacción']
# Atributos: {'href': 'https://www.huffingtonpost.es/entry/ayuso-dice-que-los-turistas-vienen-a-ver-museos-y-mamen-mendizabal-se-pasa-twitter-con-su-reaccion_es_6059f57fc5b6f12839d7b570', 'rel': [], 'target': ''}
#
#
# URL:  http://as.com/?por=mosaico
# Contenido:  [<span>As</span>]
# Atributos: {'class': ['k', 'kicker', '|', 'kicker_as_white', 'text_indent', 'width_full', '|', 'uppercase', 'color_gray_ultra_dark'], 'href': 'http://as.com/?por=mosaico'}
#
#
# URL:  https://as.com/futbol/2021/03/22/internacional/1616426470_560026.html
# Contenido:  ['Theo Hernández: "Irme del Madrid fue lo mejor para mí"']
# Atributos: {'href': 'https://as.com/futbol/2021/03/22/internacional/1616426470_560026.html', 'rel': [], 'target': ''}
#
#
# URL:  https://as.com/meristation/noticias/?por=mosaico
# Contenido:  [<span>Meristation</span>]
# Atributos: {'class': ['k', 'kicker', '|', 'kicker_meristation_white', 'text_indent', 'width_full', '|', 'uppercase', 'color_gray_ultra_dark'], 'href': 'https://as.com/meristation/noticias/?por=mosaico'}
#
#
# URL:  https://as.com/meristation/2021/03/23/noticias/1616481648_451571.html
# Contenido:  ['Marbella Vice de Ibai Llanos: qué es, fecha y streamers de la nueva serie en GTA 5']
# Atributos: {'href': 'https://as.com/meristation/2021/03/23/noticias/1616481648_451571.html', 'rel': [], 'target': ''}
#
#
# URL:  http://suscripciones.elpais.com/?prm=epm_faldonsuscribete_300614
# Contenido:  ['Suscripciones']
# Atributos: {'href': 'http://suscripciones.elpais.com/?prm=epm_faldonsuscribete_300614'}
#
#
# URL:  //redirector.kioskoymas.com/portada/elpais/2317
# Contenido:  ['Comprar ejemplar']
# Atributos: {'href': '//redirector.kioskoymas.com/portada/elpais/2317', 'class': ['button', 'button_primary', 'slim']}
#
#
# URL:  //elpais.com/hemeroteca/elpais/portadas/2021/
# Contenido:  ['Archivo de portadas >']
# Atributos: {'href': '//elpais.com/hemeroteca/elpais/portadas/2021/', 'class': ['button', 'inverted', 'slim']}
#
#
# URL:  //redirector.kioskoymas.com/portada/elpais/2289
# Contenido:  ['Comprar ejemplar']
# Atributos: {'class': ['button', 'button_primary', 'slim', 'block'], 'href': '//redirector.kioskoymas.com/portada/elpais/2289'}
#
#
# URL:  //elpais.com/hemeroteca/el-pais-semanal/portadas/2021/
# Contenido:  ['Archivo de portadas >']
# Atributos: {'class': ['button', 'inverted', 'slim', 'block'], 'href': '//elpais.com/hemeroteca/el-pais-semanal/portadas/2021/'}
#
#
# URL:  //redirector.kioskoymas.com/portada/elpais/2317/
# Contenido:  ['Comprar ejemplar']
# Atributos: {'class': ['button', 'button_primary', 'slim', 'block'], 'href': '//redirector.kioskoymas.com/portada/elpais/2317/'}
#
#
# URL:  //elviajero.elpais.com/hemeroteca/elviajero/portadas/2021/
# Contenido:  ['Archivo de portadas >']
# Atributos: {'class': ['button', 'inverted', 'slim', 'block'], 'href': '//elviajero.elpais.com/hemeroteca/elviajero/portadas/2021/'}
#
#
# URL:  //redirector.kioskoymas.com/portada/elpais/2317/
# Contenido:  ['Comprar ejemplar']
# Atributos: {'class': ['button', 'button_primary', 'slim', 'block'], 'href': '//redirector.kioskoymas.com/portada/elpais/2317/'}
#
#
# URL:  //elpais.com/hemeroteca/babelia/portadas/2021/
# Contenido:  ['Archivo de portadas >']
# Atributos: {'class': ['button', 'inverted', 'slim', 'block'], 'href': '//elpais.com/hemeroteca/babelia/portadas/2021/'}
#
#
# URL:  //redirector.kioskoymas.com/portada/elpais/2330
# Contenido:  ['Comprar ejemplar']
# Atributos: {'class': ['button', 'button_primary', 'slim', 'block'], 'href': '//redirector.kioskoymas.com/portada/elpais/2330'}
#
#
# URL:  //redirector.kioskoymas.com/portada/elpais/3725
# Contenido:  ['Comprar ejemplar']
# Atributos: {'class': ['button', 'button_primary', 'slim', 'block'], 'href': '//redirector.kioskoymas.com/portada/elpais/3725'}
#
#
# URL:  http://suscripciones.elpais.com/?id_externo_promo=suscrip-pie-home
# Contenido:  [<span>SUSCRÍBETE</span>]
# Atributos: {'class': ['k', 'kicker', '|', 'uppercase'], 'href': 'http://suscripciones.elpais.com/?id_externo_promo=suscrip-pie-home'}
#
#
# URL:  http://suscripciones.elpais.com/?id_externo_promo=suscrip-pie-home
# Contenido:  ['Descubre la suscripción que mejor se adapta a ti']
# Atributos: {'href': 'http://suscripciones.elpais.com/?id_externo_promo=suscrip-pie-home'}
#
#
# URL:  http://suscripciones.elpais.com/?id_externo_promo=suscrip-pie-home
# Contenido:  ['DESCÚBRELO ']
# Atributos: {'href': 'http://suscripciones.elpais.com/?id_externo_promo=suscrip-pie-home', 'class': ['c_r_s_h', 'related_story_headline']}
#
#
# URL:  https://elpais.com/tematicos/2021/03/16/elpaismas/1615889833_157488.html
# Contenido:  ['Encuentro con dos premios Ortega y Gasset de Periodismo']
# Atributos: {'href': 'https://elpais.com/tematicos/2021/03/16/elpaismas/1615889833_157488.html'}
#
#
# URL:  https://elpais.com/tematicos/2020/02/03/elpaismas/1580727455_194715.html
# Contenido:  ['¡PARTICIPA! ']
# Atributos: {'href': 'https://elpais.com/tematicos/2020/02/03/elpaismas/1580727455_194715.html', 'class': ['c_r_s_h', 'related_story_headline']}
#
#
# URL:  https://suscripciones.elpais.com/?prm=epm_faldonsuscr%C3%ADbete_300614
# Contenido:  [<svg class="icon_various_subscription_check icon_sm pull_left" viewbox="0 0 10 10"><g fill-rule="evenodd"><path d="M10 5a4.999 4.999 0 0 1-5 4.999A4.999 4.999 0 1 1 5 0a5 5 0 0 1 5 5"></path><path d="M7.103 2.773L4.627 5.248l-1.43-1.43-1.06 1.06L4.627 7.37l3.537-3.536z"></path></g></svg>, <span>Suscríbete</span>]
# Atributos: {'class': ['whitespace_nowrap'], 'href': 'https://suscripciones.elpais.com/?prm=epm_faldonsuscr%C3%ADbete_300614'}
#
#
# URL:  https://plus.elpais.com/newsletters/?prm=pie_newsletters_ep
# Contenido:  [<svg class="icon_various_subscription_check icon_sm pull_left" viewbox="0 0 10 10"><g fill-rule="evenodd"><path d="M10 5a4.999 4.999 0 0 1-5 4.999A4.999 4.999 0 1 1 5 0a5 5 0 0 1 5 5"></path><path d="M7.103 2.773L4.627 5.248l-1.43-1.43-1.06 1.06L4.627 7.37l3.537-3.536z"></path></g></svg>, <span>Newsletters</span>]
# Atributos: {'class': ['whitespace_nowrap'], 'href': 'https://plus.elpais.com/newsletters/?prm=pie_newsletters_ep'}
#
#
# URL:  http://www.kioskoymas.com/publicacion/elpais
# Contenido:  [<svg class="icon_various_subscription_check icon_sm pull_left" viewbox="0 0 10 10"><g fill-rule="evenodd"><path d="M10 5a4.999 4.999 0 0 1-5 4.999A4.999 4.999 0 1 1 5 0a5 5 0 0 1 5 5"></path><path d="M7.103 2.773L4.627 5.248l-1.43-1.43-1.06 1.06L4.627 7.37l3.537-3.536z"></path></g></svg>, <span>ACCEDE A KIOSKO Y MÁS | DESCÁRGATE LA APLICACIÓN: <span classname="color_blue">IOS, ANDROID, W8</span></span>]
# Atributos: {'class': ['margin_right_qtr'], 'href': 'http://www.kioskoymas.com/publicacion/elpais'}
#
#
# URL:  //elpais.com/corporativos/
# Contenido:  ['©\xa0', <span class="bold">EDICIONES EL PAÍS S.L.</span>]
# Atributos: {'class': ['gf_c'], 'href': '//elpais.com/corporativos/', 'target': '_blank', 'rel': ['noopener', 'noreferrer']}
#
#
# URL:  //elpais.com/estaticos/contacte/
# Contenido:  ['Contacto']
# Atributos: {'id': '', 'href': '//elpais.com/estaticos/contacte/', 'title': 'Contacto', 'target': '_blank', 'rel': ['noopener', 'noreferrer']}
#
#
# URL:  //www.prisanewsservices.com/
# Contenido:  ['Venta de contenidos']
# Atributos: {'id': '', 'href': '//www.prisanewsservices.com/', 'title': 'Venta de contenidos', 'target': '_blank', 'rel': ['noopener', 'noreferrer']}
#
#
# URL:  //elpais.com/estaticos/aviso-legal/
# Contenido:  ['Aviso legal']
# Atributos: {'id': '', 'href': '//elpais.com/estaticos/aviso-legal/', 'title': 'Aviso legal', 'target': '_blank', 'rel': ['noopener', 'noreferrer']}
#
#
# URL:  https://elpais.com/politica-de-cookies/
# Contenido:  ['Política cookies']
# Atributos: {'id': '', 'href': 'https://elpais.com/politica-de-cookies/', 'title': 'Política cookies', 'target': '_blank', 'rel': ['noopener', 'noreferrer']}
#
#
# URL:  #
# Contenido:  ['Configuración de cookies']
# Atributos: {'id': 'link-7PHHQT66616EHB8BN9RNNM3W5R', 'href': '#', 'title': 'Configuración de cookies', 'target': '_blank', 'rel': ['noopener', 'noreferrer']}
#
#
# URL:  https://elpais.com/estaticos/politica-privacidad/
# Contenido:  ['Política de privacidad']
# Atributos: {'id': '', 'href': 'https://elpais.com/estaticos/politica-privacidad/', 'title': 'Política de privacidad', 'target': '_blank', 'rel': ['noopener', 'noreferrer']}
#
#
# URL:  //elpais.com/estaticos/mapa-web/
# Contenido:  ['Mapa']
# Atributos: {'id': '', 'href': '//elpais.com/estaticos/mapa-web/', 'title': 'Mapa', 'target': '_blank', 'rel': ['noopener', 'noreferrer']}
#
#
# URL:  //elpais.com/landing_oferta/
# Contenido:  ['Suscripciones EL PAÍS']
# Atributos: {'id': '', 'href': '//elpais.com/landing_oferta/', 'title': 'Suscripciones EL PAÍS', 'target': '_blank', 'rel': ['noopener', 'noreferrer']}
#
#
# URL:  https://elpais.com/suscripciones/empresas/
# Contenido:  ['Suscripciones para empresas']
# Atributos: {'id': '', 'href': 'https://elpais.com/suscripciones/empresas/', 'title': 'Suscripciones para empresas', 'target': '_blank', 'rel': ['noopener', 'noreferrer']}
#
#
# URL:  //servicios.elpais.com/rss/
# Contenido:  ['RSS']
# Atributos: {'id': '', 'href': '//servicios.elpais.com/rss/', 'title': 'RSS', 'target': '_blank', 'rel': ['noopener', 'noreferrer']}
#
#
# URL:  //elpais.com/tag/listado/
# Contenido:  ['Índice de temas']
# Atributos: {'id': '', 'href': '//elpais.com/tag/listado/', 'title': 'Índice de temas', 'target': '_blank', 'rel': ['noopener', 'noreferrer']}
#
#
# URL:  https://elpais.com/actualidad/
# Contenido:  ['Noticias de hoy']
# Atributos: {'id': '', 'href': 'https://elpais.com/actualidad/', 'title': 'Noticias de hoy', 'target': '_blank', 'rel': ['noopener', 'noreferrer']}

# %% [markdown]
# Puedes encontrar la documentación de beautifulsoup en https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %% [markdown]
# <a id="ejemplos"></a>
# ## Ejemplos de web scraping

# %% [markdown]
# ### 1. Frecuencia de las palabras de un discurso
# Vamos a obtener la frecuencia de las palabras del siguiente discurso: https://elpais.com/internacional/2018/01/31/actualidad/1517387619_036241.html

# %%
import urllib.request
from bs4 import BeautifulSoup
import pandas as pd

url = "https://elpais.com/internacional/2018/01/31/actualidad/1517387619_036241.html"
html = urllib.request.urlopen(url)
soup2=BeautifulSoup(html)

tags = soup2("p")
discurso = " "
tags

for tag in tags:
    if len(tag.attrs) == 0:
        
        a = tag.contents[0] + " "
        discurso += a 
#print(discurso)
contadores = dict()
discurso = discurso.replace(",", " ").replace("."," ").replace(":"," ").replace("?"," ").replace("¿"," ")
palabras = discurso.lower().split()
for palabra in palabras:
    if len(palabra)>4:
        contadores[palabra] = contadores.get(palabra,0) +1
df = pd.DataFrame(list(contadores.items()),columns = ["palabra", "contador"])
df.sort_values(by ="contador", ascending = False)
# Out:
#               palabra  contador
# 11    estadounidenses        33
# 27            nuestro        28
# 491          nuestros        28
# 52              hemos        27
# 301           nuestra        27
# ...               ...       ...
# 705         económica         1
# 704         rendición         1
# 703           riqueza         1
# 702          llevaban         1
# 1585          américa         1
#
# [1586 rows x 2 columns]

# %%
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt

# %%
# Create and generate a word cloud image:
wordcloud = WordCloud().generate(discurso)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ### 2. Web Scraping de coinbase
# Extraemos el valor más reciente de Bitcoin en https://coinmarketcap.com/currencies/bitcoin/
# ![btc.png](attachment:btc.png)

# %%
import urllib.request
from bs4 import BeautifulSoup
url = "https://coinmarketcap.com/currencies/bitcoin/"
html = urllib.request.urlopen(url)
soup = BeautifulSoup(html)
tag = soup.find_all("div", class_ = "priceValue___11gHJ")
bitcoin = float(tag[0].contents[0].replace("$","").replace(",",""))
bitcoin

#<div class="priceValue___11gHJ">$55,984.02</div>
# Out:
# 55961.18

# %% [markdown]
# ### 3. Web scraping con pandas

# %% [markdown]
# La función `read_html()` de pandas también permite extraer tablas de páginas web, devolviendo una lista de dataframes con todas las tablas que existan.
# Por ejemplo, vamos a hacer scraping de la siguiente tabla: http://www.fdic.gov/bank/individual/failed/banklist.html
#
# Es necesario instalar la librería `lxml`: `conda install -c conda-forge lxml`

# %%
import pandas as pd
url = "https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/"
tablas = pd.read_html(url)
tablas[0]
# Out:
#                              Bank Name               City State   Cert  \
# 0                    Almena State Bank             Almena    KS  15426
# 1           First City Bank of Florida  Fort Walton Beach    FL  16748
# 2                 The First State Bank      Barboursville    WV  14361
# 3                   Ericson State Bank            Ericson    NE  18265
# 4     City National Bank of New Jersey             Newark    NJ  21111
# ..                                 ...                ...   ...    ...
# 558                 Superior Bank, FSB           Hinsdale    IL  32646
# 559                Malta National Bank              Malta    OH   6629
# 560    First Alliance Bank & Trust Co.         Manchester    NH  34264
# 561  National State Bank of Metropolis         Metropolis    IL   3815
# 562                   Bank of Honolulu           Honolulu    HI  21029
#
#                    Acquiring Institution       Closing Date
# 0                            Equity Bank   October 23, 2020
# 1              United Fidelity Bank, fsb   October 16, 2020
# 2                         MVB Bank, Inc.      April 3, 2020
# 3             Farmers and Merchants Bank  February 14, 2020
# 4                        Industrial Bank   November 1, 2019
# ..                                   ...                ...
# 558                Superior Federal, FSB      July 27, 2001
# 559                    North Valley Bank        May 3, 2001
# 560  Southern New Hampshire Bank & Trust   February 2, 2001
# 561              Banterra Bank of Marion  December 14, 2000
# 562                   Bank of the Orient   October 13, 2000
#
# [563 rows x 6 columns]

# %% [markdown]
# ### 4. Agente de usuario

# %% [markdown]
# El **agente de usuario** es un identificador con el que un programa inicia sesión en el servidor web para solicitar datos
#
# Cuando un usuario accede a una página web, la aplicación generalmente envía una cadena de texto que identifica al agente de usuario ante el servidor. Este texto forma parte de la petición a través de HTTP, llevando como prefijo
# *User-Agent*, y generalmente incluye información como el nombre de la aplicación, la versión, el sistema operativo, y el idioma.
#
# La identificación de agente de usuario es uno de los criterios de exclusión utilizado para impedir el acceso a ciertas secciones de un sitio web.

# %% [markdown]
# Ejemplo: Obtenemos la altura de los futbolistas desde la web de transfermarkt:
# https://www.transfermarkt.es/lionel-messi/profil/spieler/28003

# %%
import urllib.request
from bs4 import BeautifulSoup
url = 'https://www.transfermarkt.es/lionel-messi/profil/spieler/28003'
req = urllib.request.Request(
    url, 
    data=None, 
    headers={
        'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.47 Safari/537.36'
    }
)

f = urllib.request.urlopen(req)
soup = BeautifulSoup(f)
tags = soup.find_all(attrs={"itemprop" : "height"})
#tags
altura = float(tags[0].contents[0].replace(' m','').replace(',','.'))
altura
# Out:
# 1.7

# %% [markdown]
# ## <span style="color:red">Ejemplo</span>

# %% [markdown]
# Obtén los equipos que hayan ganado LaLiga en los últimos 10 años con su puntuación a partir de la siguiente URL: https://resultados.as.com/resultados/futbol/primera/2019_2020/clasificacion/
#
# | Temporada | Club        | Puntos |
# |-----------|-------------|--------|
# | 19/20     | Real Madrid | 87     |
# | 18/19     | Barcelona   | 87     |
# | ...       | ...         | ...    |

# %%
#import urllib.request
#from sb4 import Beautiful.Soup


import pandas as pd 
dfTotal = pd.DataFrame()

for temp in range(10,20):
    temporada = "20"+str(temp)+"_"+"20"+str(temp+1)
    url = "https://resultados.as.com/resultados/futbol/primera/"+temporada+"/clasificacion/"
    tabla = pd.read_html(url)
    T = tabla[0]
    equipo = T.iloc[0,0].replace("1"," ").strip()
    puntos = T.iloc[0,1]
    df =pd.DataFrame({"Temporada":[temporada],
                     "Equipo":[equipo],
                     "Puntos":[puntos]})
    dfTotal = pd.concat([dfTotal,df], axis = 0)
dfTotal = dfTotal.reset_index(drop=True)
dfTotal
# Out:
#    Temporada       Equipo  Puntos
# 0  2010_2011    Barcelona      96
# 1  2011_2012  Real Madrid     100
# 2  2012_2013    Barcelona     100
# 3  2013_2014     Atlético      90
# 4  2014_2015    Barcelona      94
# 5  2015_2016    Barcelona      91
# 6  2016_2017  Real Madrid      93
# 7  2017_2018    Barcelona      93
# 8  2018_2019    Barcelona      87
# 9  2019_2020  Real Madrid      87

# %%
tabla = pd.read_html(url)
T = tabla[0]
equipo = T.iloc[0,0].replace("1"," ").strip()
puntos = T.iloc[0,1]
df =pd.DataFrame({"Temporada":["19/20"],
                 "Equipo":[equipo],
                 "Puntos":[puntos]})
df

# %% [markdown]
# <a id="sele"></a>
# ## Web Scraping con Selenium

# %% [markdown]
# Selenium es una librería que permite automatizar navegadores web
#
# Es necesario disponer del siguiente driver: http://chromedriver.chromium.org/downloads
#
# Documentación: https://selenium-python.readthedocs.io/
#
# Para instalar la librería, desde anaconda prompt:
#
# `conda install -c conda-forge selenium`
#
# En este ejemplo vamos a extraer datos climáticos de la web http://eportal.mapa.gob.es/websiar/SeleccionParametrosMap.aspx?dst=1

# %% [markdown]
# [Link al Notebook](./Web%20Scraping%20con%20Selenium.ipynb)
